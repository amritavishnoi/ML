# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd

# %%
emp = pd.read_csv("employee.csv")

# %%
emp.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
emp.shape
# Out:
# (1470, 35)

# %%
emp.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
emp.corr()
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %%
print (emp.EmployeeCount.unique())
print (emp.EmployeeNumber.unique())
print (emp.Over18.unique())
print (emp.StandardHours.unique())
# Out:
# [1]
# [   1    2    4 ... 2064 2065 2068]
# ['Y']
# [80]

# %%
### in above code there is no unique value

# %%
#dropping the unnecessary columns
employee = emp.drop(['EmployeeCount','EmployeeNumber','Over18','StandardHours'],axis=1)

# %%
employee.shape
# Out:
# (1470, 31)

# %%
# Dummy variables
employee['Attrition']=np.where(employee['Attrition']=='Yes',1,0)

# %%
employee.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %%
print(employee.BusinessTravel.value_counts())
print('***************************************')
print(employee.Department.value_counts())
print('***************************************')
print(employee.EducationField.value_counts())
print('***************************************')
print(employee.JobRole.value_counts())
print('***************************************')
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
# ***************************************
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64
# ***************************************
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64
# ***************************************
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64
# ***************************************

# %%
#encoding categorical variables into numerical variables
employee_dummies=pd.get_dummies(employee[['BusinessTravel','Department','EducationField','Gender',\
                                          'JobRole','MaritalStatus','OverTime']],drop_first=True)

# %%
employee=employee.drop(['BusinessTravel','Department','EducationField','Gender',
                        'JobRole','MaritalStatus','OverTime'],axis=1)

# %%
employee=pd.concat([employee,employee_dummies],axis=1)

# %%
employee.head()
employee.shape
# Out:
# (1470, 45)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier

classfier = KNeighborsClassifier(n_neighbors=5)
classfier.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
from sklearn.neighbors import KNeighborsClassifier

#classfier = KNeighborsClassifier(metric='euclidean' ,n_neighbors=9)

classfier = KNeighborsClassifier(n_neighbors=7)
classfier.fit(X_train,y_train)

y_pred = classfier.predict(X_test)

from sklearn import metrics

print("Accuracy: " ,metrics.accuracy_score(y_test,y_pred))

#1= 0.8390022675736961
# 7 =  0.8412698412698413
# 10 = 0.8412698412698413
# 13 =  0.8412698412698413
#20 = 0.8412698412698413
# Out:
# Accuracy:  0.8412698412698413

# %%
#amrita make different variables for
#both the models and different prediction variable also , they are getting mixed up

#also only play with one parameter I,e k value , don't change the value of metric

# %%
# finding the appropriate value of K using cross validation
from sklearn.model_selection import cross_val_score
accuracy_rate = []

for i in range(1,40):
    
    knn = KNeighborsClassifier(n_neighbors=i)
    score=cross_val_score(knn,x,y,cv=10)
    accuracy_rate.append(score.mean())

# %%
import matplotlib.pyplot as plt

plt.figure(figsize= (10,6))
plt.plot(range(1,40),accuracy_rate,color='blue',marker='.',markerfacecolor='red',markersize=10)
plt.title("accuracy vs k value")
plt.xlabel('K')
plt.ylabel('accuracy_rate')
# Out:
# Text(0, 0.5, 'accuracy_rate')

# %%
# accuracy vs K_value for identifying the appropriate value of K
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
plt.plot(range(1,40),accuracy_rate,color='blue', marker='.',
         markerfacecolor='red', markersize=10)
plt.title('accuracy_rate vs. K Value')
plt.xlabel('K')
plt.ylabel('accuracy_rate')
# Out:
# Text(0, 0.5, 'accuracy_rate')
